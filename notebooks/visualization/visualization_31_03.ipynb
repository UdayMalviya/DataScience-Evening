# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 24.9 KB

# %%
sns.set_theme()

# %%
#box plot
sns.boxplot(df, x='sex', y='bill_depth_mm', hue='island', fill=False)
# Out:
# <Axes: xlabel='sex', ylabel='bill_depth_mm'>

# %%
sns.violinplot(df, x='sex', y='bill_depth_mm', hue='island', fill=False)
# Out:
# <Axes: xlabel='sex', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(df, x='sex', y='bill_depth_mm', hue='island')
# Out:
# <Axes: xlabel='sex', ylabel='bill_depth_mm'>

# %%
# pairplot 
sns.pairplot(df)

# %%
# heatmaps
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 24.9 KB

# %%
data = df.select_dtypes(['int', 'float'])

# %%
data.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data.corr(), center=0, annot =data.corr())
# Out:
# <Axes: >

# %%
sns.set_theme(style='white')

# %%
x = np.linspace(1, 10, 50)
y = np.log(x)
s = np.random.rand(len(x))
sns.scatterplot(x=x, y=y, size=s, hue=x, palette='rocket', legend=None)
# Out:
# <Axes: >

# %%
sns.cubehelix_palette(start=.2, rot=-.3, as_cmap=True)

# %%
sns.set_theme()

# %%
data = df.sample(100)

# %%
data
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 31      Adelie   Dream            37.2           18.1              178.0
# 308     Gentoo  Biscoe            47.5           14.0              212.0
# 51      Adelie  Biscoe            40.1           18.9              188.0
# 225     Gentoo  Biscoe            46.5           13.5              210.0
# 89      Adelie   Dream            38.9           18.8              190.0
# ..         ...     ...             ...            ...                ...
# 138     Adelie   Dream            37.0           16.5              185.0
# 159  Chinstrap   Dream            51.3           18.2              197.0
# 95      Adelie   Dream            40.8           18.9              208.0
# 269     Gentoo  Biscoe            45.2           15.8              215.0
# 94      Adelie   Dream            36.2           17.3              187.0
#
#      body_mass_g     sex
# 31        3900.0    Male
# 308       4875.0  Female
# ...

# %%
pd.concat((df, data), axis=1)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex species     island  bill_length_mm  bill_depth_mm  \
# ...

# %%
df.shape
# Out:
# (344, 7)

# %%
pd.merge(df, data, how='inner', on='species')
# Out:
#       species   island_x  bill_length_mm_x  bill_depth_mm_x  \
# 0      Adelie  Torgersen              39.1             18.7
# 1      Adelie  Torgersen              39.1             18.7
# 2      Adelie  Torgersen              39.1             18.7
# 3      Adelie  Torgersen              39.1             18.7
# 4      Adelie  Torgersen              39.1             18.7
# ...       ...        ...               ...              ...
# 13039  Gentoo     Biscoe              49.9             16.1
# 13040  Gentoo     Biscoe              49.9             16.1
# 13041  Gentoo     Biscoe              49.9             16.1
# 13042  Gentoo     Biscoe              49.9             16.1
# 13043  Gentoo     Biscoe              49.9             16.1
#
#        flipper_length_mm_x  body_mass_g_x sex_x island_y  bill_length_mm_y  \
# 0                    181.0         3750.0  Male    Dream              37.2
# 1                    181.0         3750.0  Male   Biscoe              40.1
# ...

# %%
df.join(data, rsuffix='__123', how='inner')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 21   Adelie     Biscoe            37.7           18.7              180.0
# ..      ...        ...             ...            ...                ...
# 329  Gentoo     Biscoe            48.1           15.1              209.0
# 330  Gentoo     Biscoe            50.5           15.2              216.0
# 332  Gentoo     Biscoe            43.5           15.2              213.0
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
#
#      body_mass_g     sex species__123 island__123  bill_length_mm__123  \
# ...

# %%
1|\n'abc'|\n"40000"

# %%
print("Hello world", end='-')
print("this is pandas")
# Out:
# Hello world-this is pandas

# %%
print("Hello_world", 'this_is_python', sep='-')
# Out:
# Hello_world-this_is_python

# %%
df.to_csv('file.csv', index=False, sep='|')

# %%
pd.read_csv('file.csv', sep='|')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
id(df)
# Out:
# 2249597266512

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
a = 6 
b = 7

# %%
id(a)
# Out:
# 140725936055576

# %%
id(b)
# Out:
# 140725936055608

# %%
a = 89

# %%
id(6)
# Out:
# 140725936055576

# %%
id(a)
# Out:
# 140725936058232

# %%
del a

# %%
id(89)
# Out:
# 140725936058232

# %%
pd.cut(df['bill_length_mm'], bins=30)
# Out:
# 0      (38.517, 39.433]
# 1       (39.433, 40.35]
# 2       (39.433, 40.35]
# 3                   NaN
# 4        (36.683, 37.6]
#              ...
# 339                 NaN
# 340    (46.767, 47.683]
# 341    (49.517, 50.433]
# 342     (44.933, 45.85]
# 343    (49.517, 50.433]
# Name: bill_length_mm, Length: 344, dtype: category
# Categories (30, interval[float64, right]): [(32.072, 33.017] < (33.017, 33.933] < (33.933, 34.85] < (34.85, 35.767] ... (55.933, 56.85] < (56.85, 57.767] < (57.767, 58.683] < (58.683, 59.6]]

# %%
pd.get_dummies(df['sex'], drop_first=True)
# Out:
#       Male
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 339  False
# 340  False
# 341   True
# 342  False
# 343   True
#
# [344 rows x 1 columns]
