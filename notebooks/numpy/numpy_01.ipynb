# %%
import numpy as np

# %%
# array creation

lst = [1,2,3]

# %%
type(np.array(lst))
# Out:
# numpy.ndarray

# %%
np.array(lst)
# Out:
# array([1, 2, 3])

# %%
ls = list(range(500000))

# %%
# %%timeit
l = []
for i in ls:
    l.append(i*2)
# Out:
# 58.1 ms ± 1.49 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
np.array(ls)*2
# Out:
# 39.9 ms ± 2.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
a =np.array([[1,2,3], [5,6,7]])

# %%
set(range(1,10,2) )
# Out:
# {1, 3, 5, 7, 9}

# %%
np.arange(3,10, 4)
# Out:
# array([3, 7])

# %%
#shape, size, ndim,

# %%
# shape
arr.shape
# Out:
# (3,)

# %%
a.shape, a
# Out:
# ((2, 3),
#  array([[1, 2, 3],
#         [5, 6, 7]]))

# %%
# size
a.size, arr.size
# Out:
# (6, 3)

# %%
a.ndim
# Out:
# 2

# %%
a
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
np.array(4).dtype
# Out:
# dtype('int64')

# %%
# 0D numpy scaler
# 1D vector
# 2D Matrix
# 3D+ Tensor

# %%
np.array([3.6,6.7]).dtype
# Out:
# dtype('float64')

# %%
np.array([True, False]).dtype
# Out:
# dtype('bool')

# %%
np.array(['ABD', 'B'])
# Out:
# array(['ABD', 'B'], dtype='<U3')

# %%
# np.array
# np.arange
# shape, size, ndim, dtype
