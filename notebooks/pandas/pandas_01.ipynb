# %% [markdown]
# pip install pandas

# %%
# data clean
# transform
# manage

# %%
import pandas as pd

# %%
# Series
# DataFrames (collection of dataframe)

# %%
s = pd.Series([1,2,3.5,4])

# %%
df = pd.DataFrame({'A':[1,2,3,4], "B": [4,5,8,10]})

# %%
s + 3
# Out:
# 0    4.0
# 1    5.0
# 2    6.5
# 3    7.0
# dtype: float64

# %%
s / 4
# Out:
# 0    0.250
# 1    0.500
# 2    0.875
# 3    1.000
# dtype: float64

# %%
s < 4
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
df
# Out:
#    A   B
# 0  1   4
# 1  2   5
# 2  3   8
# 3  4  10

# %%
s.shape, df.shape
# Out:
# ((4,), (4, 2))

# %%
# load data
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
s = pd.Series([1,2,3,4], index=["a", "b", "c", "d"], name="Series_", dtype='int64')

# %%
s.name
# Out:
# 'Series_'

# %%
s.dtype
# Out:
# dtype('int64')

# %%
type(s)
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s['a']
# Out:
# np.int64(1)

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: Series_, dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df["population"].index
# Out:
# RangeIndex(start=0, stop=17000, step=1)

# %%
df[["population", "longitude"]]
# Out:
#        population  longitude
# 0          1015.0    -114.31
# 1          1129.0    -114.47
# 2           333.0    -114.56
# 3           515.0    -114.57
# 4           624.0    -114.57
# ...           ...        ...
# 16995       907.0    -124.26
# 16996      1194.0    -124.27
# 16997      1244.0    -124.30
# 16998      1298.0    -124.30
# 16999       806.0    -124.35
#
# [17000 rows x 2 columns]

# %%
df.columns[2]
# Out:
# 'housing_median_age'

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
s.sum()
# Out:
# np.int64(10)

# %%
df.sum()
# Out:
# longitude            -2.032556e+06
# latitude              6.056288e+05
# housing_median_age    4.860190e+05
# total_rooms           4.494230e+07
# total_bedrooms        9.169984e+06
# population            2.430276e+07
# households            8.520773e+06
# median_income         6.602083e+04
# median_house_value    3.524116e+09
# dtype: float64

# %%
import numpy as np

# %%
a = s.to_numpy()

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a =a.astype(np.int8)

# %%
a.itemsize # in bytes 8 bit = 1 byte
# Out:
# 1

# %%
a
# Out:
# array([1, 2, 3, 4], dtype=int8)

# %%
a.astype("int64").dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
s.astype("int32")
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: Series_, dtype: int32

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe(include='all') # statistical overview
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# outlier

# %%
df['households']
# Out:
# 0        472.0
# 1        463.0
# 2        117.0
# 3        226.0
# 4        262.0
#          ...
# 16995    369.0
# 16996    465.0
# 16997    456.0
# 16998    478.0
# 16999    270.0
# Name: households, Length: 17000, dtype: float64

# %%
# loc, iloc
df.loc[[0, 1]] # Fancy indexing
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df.loc[2:100, ["total_bedrooms", 'population']]
# Out:
#      total_bedrooms  population
# 2             174.0       333.0
# 3             337.0       515.0
# 4             326.0       624.0
# 5             236.0       671.0
# 6             680.0      1841.0
# ..              ...         ...
# 96            203.0       533.0
# 97            507.0       762.0
# 98            414.0      1416.0
# 99            274.0       862.0
# 100           307.0      1000.0
#
# [99 rows x 2 columns]

# %%
df.loc[0:4, -1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_299/966215818.py in <cell line: 0>()
# ----> 1 df.loc[0:4, -1]
#
# ...

# %%
d = {"A": 0}
d['B']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_299/1735476600.py in <cell line: 0>()
#       1 d = {"A": 0}
# ----> 2 d['B']
#
# KeyError: 'B'

# %%
a[[0, 2]]
# Out:
# array([1, 3], dtype=int8)

# %%
s['a':"c"] = 10, 10, 20

# %%
s["a":"c"]
# Out:
# a    10
# b    10
# c    20
# Name: Series_, dtype: int64

# %%
# df = 0
data = df.copy() # shallow

# %%
data[:] = df

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# head, tail, sample
df.head(10) # top 5 rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.tail(30) # bottom 5
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16970    -124.17     40.80                52.0       1606.0           419.0
# 16971    -124.17     40.80                52.0       1557.0           344.0
# 16972    -124.17     40.79                43.0       2285.0           479.0
# 16973    -124.17     40.78                39.0       1606.0           330.0
# 16974    -124.17     40.77                30.0       1895.0           366.0
# 16975    -124.17     40.76                26.0       1776.0           361.0
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16977    -124.17     40.62                32.0       1595.0           309.0
# 16978    -124.18     40.79                39.0       1836.0           352.0
# 16979    -124.18     40.78                37.0       1453.0           293.0
# 16980    -124.18     40.78                34.0       1592.0           364.0
# ...

# %%
df.sample(20) # random 1 row
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5735     -118.19     34.04                40.0       1095.0           305.0
# 14709    -122.19     38.09                 8.0        614.0           118.0
# 13979    -122.04     37.66                10.0       2031.0           357.0
# 12146    -121.44     36.84                 7.0       1644.0           338.0
# 13583    -121.97     37.01                21.0       2073.0           357.0
# 2950     -117.77     33.70                 3.0       3636.0           749.0
# 16705    -122.83     38.89                11.0        640.0           134.0
# 523      -117.00     32.85                24.0       1888.0           319.0
# 14902    -122.23     38.10                47.0       1303.0           278.0
# 2949     -117.77     33.70                 4.0       2446.0           622.0
# 3961     -117.96     33.82                29.0       2176.0           468.0
# ...

# %%
8
