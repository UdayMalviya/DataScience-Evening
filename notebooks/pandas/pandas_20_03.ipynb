# %%
import pandas as pd
import numpy as np

# %%
# pivot tables => summ. table

df = pd.DataFrame({"Name": ['A', 'B', 'C', 'A', 'B', 'C'], 
                  "Salary": np.random.randint(10000, 50000, 6)})

# %%
df.pivot(columns='Name')
# Out:
#        Salary
# Name        A        B        C
# 0     18592.0      NaN      NaN
# 1         NaN  18213.0      NaN
# 2         NaN      NaN  48228.0
# 3     27634.0      NaN      NaN
# 4         NaN  26257.0      NaN
# 5         NaN      NaN  41705.0

# %%
df.pivot_table(columns='Name', fill_value=0, aggfunc=["mean", "count"])  #mean
# Out:
#            mean                   count
# Name          A        B        C     A  B  C
# Salary  23113.0  22235.0  44966.5     2  2  2

# %%
df
# Out:
#   Name  Salary
# 0    A   18592
# 1    B   18213
# 2    C   48228
# 3    A   27634
# 4    B   26257
# 5    C   41705

# %%
data
# Out:
#             id                 name  state_id state_code         state_name  \
# 0           52            Ashkāsham      3901        BDS         Badakhshan
# 1           68             Fayzabad      3901        BDS         Badakhshan
# 2           78                 Jurm      3901        BDS         Badakhshan
# 3           84              Khandūd      3901        BDS         Badakhshan
# 4          115            Rāghistān      3901        BDS         Badakhshan
# ...        ...                  ...       ...        ...                ...
# 148056  131496             Redcliff      1957         MI  Midlands Province
# 148057  131502             Shangani      1957         MI  Midlands Province
# 148058  131503             Shurugwi      1957         MI  Midlands Province
# 148059  131504    Shurugwi District      1957         MI  Midlands Province
# 148060  131508  Zvishavane District      1957         MI  Midlands Province
#
# ...

# %%
data = pd.read_csv(r"D:\cities.csv")

# %%
data.pivot_table(columns=["name", "country_name"], index="state_name", values="state_id", fill_value=0.0)
# Out:
# name                   'Ali Sabieh 's Gravenmoer 's-Gravenland 's-Gravenzande  \
# country_name              Djibouti   Netherlands   Netherlands    Netherlands
# state_name
# 'Adan Governorate              0.0           0.0           0.0            0.0
# 'Amran Governorate             0.0           0.0           0.0            0.0
# 'Asir                          0.0           0.0           0.0            0.0
# A'ana                          0.0           0.0           0.0            0.0
# Aargau                         0.0           0.0           0.0            0.0
# ...                            ...           ...           ...            ...
# Žirovnica Municipality         0.0           0.0           0.0            0.0
# Žužemberk Municipality         0.0           0.0           0.0            0.0
# Șoldănești District            0.0           0.0           0.0            0.0
# Ștefan Vodă District           0.0           0.0           0.0            0.0
# ...

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.pivot_table(columns=["Pclass", "Embarked"], index="Survived", values="Fare").T.loc[1].loc["C", 0]
# Out:
# np.float64(78.84198076923077)

# %%
pivot_ = df.pivot_table(columns=["Pclass", "Embarked"], index="Survived", values="Fare").T

# %%
df[(df['Pclass']==1) & (df['Embarked'] == 'C')& (df['Survived']==0)]['Fare'].mean()
# Out:
# np.float64(78.84198076923077)

# %%
df[(df['Pclass']==1) & (df['Embarked'] == 'C')& (df['Survived']==0)]['Fare'].mean()
# Out:
# np.float64(78.84198076923077)

# %%
# pivot tables long-to-wide

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
# Pclass             1                           2                            3  \
# Embarked           C     Q          S          C      Q          S          C
# Survived
# 0          78.841981  90.0  57.260926  25.418225  12.35  18.946591   9.878361
# 1         116.121754  90.0  79.750114  25.305100  12.35  21.926316  13.404668
#
# Pclass
# Embarked          Q          S
# Survived
# 0         11.654167  14.529906
# 1         10.398770  15.131464

# %%
data.loc[0, 1]['Q']
# Out:
# np.float64(90.0)

# %%
data
# Out:
# Pclass             1                           2                            3  \
# Embarked           C     Q          S          C      Q          S          C
# Survived
# 0          78.841981  90.0  57.260926  25.418225  12.35  18.946591   9.878361
# 1         116.121754  90.0  79.750114  25.305100  12.35  21.926316  13.404668
#
# Pclass
# Embarked          Q          S
# Survived
# 0         11.654167  14.529906
# 1         10.398770  15.131464

# %%
pivot_.T.melt() # wide-to-long
# Out:
#     Pclass Embarked       value
# 0        1        C   78.841981
# 1        1        C  116.121754
# 2        1        Q   90.000000
# 3        1        Q   90.000000
# 4        1        S   57.260926
# 5        1        S   79.750114
# 6        2        C   25.418225
# 7        2        C   25.305100
# 8        2        Q   12.350000
# 9        2        Q   12.350000
# 10       2        S   18.946591
# 11       2        S   21.926316
# 12       3        C    9.878361
# 13       3        C   13.404668
# 14       3        Q   11.654167
# 15       3        Q   10.398770
# 16       3        S   14.529906
# 17       3        S   15.131464

# %%
pivot_.T
# Out:
# Pclass             1                           2                            3  \
# Embarked           C     Q          S          C      Q          S          C
# Survived
# 0          78.841981  90.0  57.260926  25.418225  12.35  18.946591   9.878361
# 1         116.121754  90.0  79.750114  25.305100  12.35  21.926316  13.404668
#
# Pclass
# Embarked          Q          S
# Survived
# 0         11.654167  14.529906
# 1         10.398770  15.131464

# %%
data.stack(level="Pclass").unstack()
# Out:
# Embarked           C                           Q                            S  \
# Pclass             1          2          3     1      2          3          1
# Survived
# 0          78.841981  25.418225   9.878361  90.0  12.35  11.654167  57.260926
# 1         116.121754  25.305100  13.404668  90.0  12.35  10.398770  79.750114
#
# Embarked
# Pclass            2          3
# Survived
# 0         18.946591  14.529906
# 1         21.926316  15.131464

# %%
data.stack(level=['Pclass'])
# Out:
# Embarked                  C          Q          S
# Survived Pclass
# 0        1        78.841981  90.000000  57.260926
#          2        25.418225  12.350000  18.946591
#          3         9.878361  11.654167  14.529906
# 1        1       116.121754  90.000000  79.750114
#          2        25.305100  12.350000  21.926316
#          3        13.404668  10.398770  15.131464

# %%
df['Sex'].map(lambda x: True if str(x)== 'female' else False, )
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
# time series dataset
# 'UTC' +00:00 +05:30
# 2024-10-29 12:45:32

# %%
import datetime
pd.to_datetime((datetime.datetime(2024, 10, 4, 4, 35)))
# Out:
# Timestamp('2024-10-04 04:35:00')

# %%
date = pd.date_range('2025-01-01', end='2025-01-30', freq='h')

# %%
pd.date_range('2025-01-01', end='2025-01-30', freq='h').min()
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
df = pd.DataFrame({"Date": date, 
             "Number": np.random.randint(1000, 5000, len(date))})

# %%
# df.to_json("date.json")
# Out:
# C:\Users\udaym\AppData\Local\Temp\ipykernel_2656\819057050.py:1: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   df.to_json("date.json")

# %%
pd.date_range('2025-01-01', end='2025-01-30', freq='h', tz = "Asia/Kolkata")
# Out:
# DatetimeIndex(['2025-01-01 00:00:00+05:30', '2025-01-01 01:00:00+05:30',
#                '2025-01-01 02:00:00+05:30', '2025-01-01 03:00:00+05:30',
#                '2025-01-01 04:00:00+05:30', '2025-01-01 05:00:00+05:30',
#                '2025-01-01 06:00:00+05:30', '2025-01-01 07:00:00+05:30',
#                '2025-01-01 08:00:00+05:30', '2025-01-01 09:00:00+05:30',
#                ...
#                '2025-01-29 15:00:00+05:30', '2025-01-29 16:00:00+05:30',
#                '2025-01-29 17:00:00+05:30', '2025-01-29 18:00:00+05:30',
#                '2025-01-29 19:00:00+05:30', '2025-01-29 20:00:00+05:30',
#                '2025-01-29 21:00:00+05:30', '2025-01-29 22:00:00+05:30',
#                '2025-01-29 23:00:00+05:30', '2025-01-30 00:00:00+05:30'],
#               dtype='datetime64[us, Asia/Kolkata]', length=697, freq='h')

# %%
# us  = micro seconds
# ns = nano seconds
pd.to_datetime(df['Date'], errors="coerce") # nan nat
# Out:
# 0     2025-01-01 00:00:00
# 1     2025-01-01 01:00:00
# 2     2025-01-01 02:00:00
# 3     2025-01-01 03:00:00
# 4     2025-01-01 04:00:00
#               ...
# 692   2025-01-29 20:00:00
# 693   2025-01-29 21:00:00
# 694   2025-01-29 22:00:00
# 695   2025-01-29 23:00:00
# 696   2025-01-30 00:00:00
# Name: Date, Length: 697, dtype: datetime64[us]

# %%
df['Date'].dt.date
# Out:
# 0      2025-01-01
# 1      2025-01-01
# 2      2025-01-01
# 3      2025-01-01
# 4      2025-01-01
#           ...
# 692    2025-01-29
# 693    2025-01-29
# 694    2025-01-29
# 695    2025-01-29
# 696    2025-01-30
# Name: Date, Length: 697, dtype: object

# %%
df['Date'].dt.time
# Out:
# 0      00:00:00
# 1      01:00:00
# 2      02:00:00
# 3      03:00:00
# 4      04:00:00
#          ...
# 692    20:00:00
# 693    21:00:00
# 694    22:00:00
# 695    23:00:00
# 696    00:00:00
# Name: Date, Length: 697, dtype: object

# %%
df['Date'].dt.day
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 692    29
# 693    29
# 694    29
# 695    29
# 696    30
# Name: Date, Length: 697, dtype: int32

# %%
df['Date'].dt.month
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 692    1
# 693    1
# 694    1
# 695    1
# 696    1
# Name: Date, Length: 697, dtype: int32

# %%
df.set_index('Date', inplace=True)

# %%
df.loc['2025-01-01']
# Out:
#                      Number
# Date
# 2025-01-01 00:00:00    3625
# 2025-01-01 01:00:00    3704
# 2025-01-01 02:00:00    3732
# 2025-01-01 03:00:00    3890
# 2025-01-01 04:00:00    3657
# 2025-01-01 05:00:00    4899
# 2025-01-01 06:00:00    2735
# 2025-01-01 07:00:00    3430
# 2025-01-01 08:00:00    2581
# 2025-01-01 09:00:00    1795
# 2025-01-01 10:00:00    3317
# 2025-01-01 11:00:00    2461
# 2025-01-01 12:00:00    4323
# 2025-01-01 13:00:00    4764
# 2025-01-01 14:00:00    2997
# 2025-01-01 15:00:00    3959
# 2025-01-01 16:00:00    4832
# 2025-01-01 17:00:00    2370
# 2025-01-01 18:00:00    2214
# 2025-01-01 19:00:00    1057
# 2025-01-01 20:00:00    3389
# 2025-01-01 21:00:00    4296
# 2025-01-01 22:00:00    1636
# 2025-01-01 23:00:00    4252
