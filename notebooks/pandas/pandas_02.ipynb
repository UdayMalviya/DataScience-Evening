# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# group by
# groupby 
df.groupby(["Pclass", "Survived"])[['Age', "SibSp"]].max() #'+'
# Out:
#                   Age  SibSp
# Pclass Survived
# 1      0         71.0      3
#        1         80.0      3
# 2      0         70.0      2
#        1         62.0      3
# 3      0         74.0      8
#        1         63.0      4

# %%
df[(df['Pclass'] == 1 ) & (df['Survived']==0)]['Age'].max()
# Out:
# np.float64(71.0)

# %%
df.groupby(["Pclass", "Survived"])[['Age', "SibSp"]].agg(["mean", "sum", "count"]).T
# Out:
# Pclass                 1                         2                         3  \
# Survived               0            1            0            1            0
# Age   mean     43.695312    35.368197    33.544444    25.901566    26.555556
#       sum    2796.500000  4314.920000  3019.000000  2149.830000  7170.000000
#       count    64.000000   122.000000    90.000000    83.000000   270.000000
# SibSp mean      0.287500     0.492647     0.319588     0.494253     0.672043
#       sum      23.000000    67.000000    31.000000    43.000000   250.000000
#       count    80.000000   136.000000    97.000000    87.000000   372.000000
#
# Pclass
# Survived               1
# Age   mean     20.646118
#       sum    1754.920000
#       count    85.000000
# SibSp mean      0.436975
#       sum      52.000000
#       count   119.000000

# %%
# concat, join, merge 
# %ls
# Out:
#  Volume in drive E is DRIVE
#  Volume Serial Number is EBC5-C7F0
#
#  Directory of E:\class_repos\DataScience_evening\Data
#
# 2026-03-17  07:04 PM    <DIR>          .
# 2026-03-18  05:37 PM    <DIR>          ..
# 2026-03-17  07:04 PM            62,894 data.csv
# 2026-03-17  05:40 PM             3,258 gender_submission.csv
# 2026-03-17  05:40 PM            28,629 test.csv
# 2026-03-17  05:40 PM            61,194 train.csv
#                4 File(s)        155,975 bytes
#                2 Dir(s)  73,194,754,048 bytes free

# %%
test = pd.read_csv("../../Data/test.csv")
submission = pd.read_csv("../../Data/gender_submission.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
pd.concat([test, submission], axis=1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
test.shape, submission.shape
# Out:
# ((418, 11), (418, 2))

# %%
418 + 418
# Out:
# 836

# %%
test.index = pd.RangeIndex(start=2 , stop=420, name="idx")

# %%
test.index
# Out:
# RangeIndex(start=2, stop=420, step=1, name='idx')

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# idx
# 2            892       3                              Kelly, Mr. James
# 3            893       3              Wilkes, Mrs. James (Ellen Needs)
# 4            894       2                     Myles, Mr. Thomas Francis
# 5            895       3                              Wirz, Mr. Albert
# 6            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 415         1305       3                            Spector, Mr. Woolf
# 416         1306       1                  Oliva y Ocana, Dona. Fermina
# 417         1307       3                  Saether, Mr. Simon Sivertsen
# 418         1308       3                           Ware, Mr. Frederick
# 419         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# idx
# ...

# %%
data = pd.concat([test.reset_index(drop=True), submission.loc[:, 'Survived']], axis=1) # must match index

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 420 entries, 2 to 1
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    float64
#  1   Pclass       418 non-null    float64
#  2   Name         418 non-null    str
#  3   Sex          418 non-null    str
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    float64
#  6   Parch        418 non-null    float64
#  7   Ticket       418 non-null    str
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     str
#  10  Embarked     418 non-null    str
#  11  Survived     418 non-null    float64
# dtypes: float64(7), str(5)
# memory usage: 59.6 KB

# %%
data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.concat((df, data))
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.join()

# %%
df.join(data, lsuffix="__", how='inner', on="PassengerId")
# Out:
#      PassengerId__  Survived__  Pclass__  \
# 0                1           0         3
# 1                2           1         1
# 2                3           1         3
# 3                4           1         1
# 4                5           0         3
# ..             ...         ...       ...
# 412            413           1         1
# 413            414           0         2
# 414            415           1         3
# 415            416           0         3
# 416            417           1         2
#
#                                                 Name__   Sex__  Age__  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
pd.merge(df, data)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
d1 = pd.DataFrame({'Name':["A", "B", "C", 'D', "E"],
                  "salary": np.random.randint(10000, 100000, 5)} )

# %%
d1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   salary  5 non-null      int32
# dtypes: int32(1), str(1)
# memory usage: 197.0 bytes

# %%
d2 = pd.DataFrame({'Name':["E", "B", "G", 'D'],
                  "salary": np.random.randint(10000, 100000, 4)} )

# %%
d1
# Out:
#   Name  salary
# 0    A   76555
# 1    B   58586
# 2    C   73041
# 3    D   70849
# 4    E   10772

# %%
d2
# Out:
#   Name  salary
# 0    E   85816
# 1    B   87099
# 2    G   24182
# 3    D   96966

# %%
pd.merge(d1, d2, how='outer', on='Name', )
# Out:
#   Name  salary_x  salary_y
# 0    A   76555.0       NaN
# 1    B   58586.0   87099.0
# 2    C   73041.0       NaN
# 3    D   70849.0   96966.0
# 4    E   10772.0   85816.0
# 5    G       NaN   24182.0

# %%
d1.rename({"Name": 'name'}, axis=1, inplace=True)

# %%
d1
# Out:
#   name  salary
# 0    A   76555
# 1    B   58586
# 2    C   73041
# 3    D   70849
# 4    E   10772

# %%
pd.merge(d1, d2, how='inner', left_on='name', right_on='Name' )
# Out:
#   name  salary_x Name  salary_y
# 0    B     58586    B     87099
# 1    D     70849    D     96966
# 2    E     10772    E     85816

# %%
df.rename_axis({0: "A"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14748\1241093349.py in ?()
# ----> 1 df.rename_axis({0: "A"})
#
# E:\class_repos\DataScience_evening\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, mapper, index, columns, axis, copy, inplace)
#    1251             )
#    1252             if non_mapper:
#    1253                 return self._set_axis_name(mapper, axis=axis, inplace=inplace)
#    1254             else:
# -> 1255                 raise ValueError("Use `.rename` to alter labels with a mapper.")
#    1256         else:
#    1257             # Use new behavior.  Means that index and/or columns
#    1258             # is specified
#
# ValueError: Use `.rename` to alter labels with a mapper.
