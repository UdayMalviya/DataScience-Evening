# %%
import seaborn as sns
import numpy as np

# %%
from sklearn.datasets import *

# %%
X, y = make_regression(n_features=1)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
X = X.flatten() + np.random.randint(0, 10, 100)

# %%
X.shape
# Out:
# (100,)

# %%
sns.regplot(x=X, y=y)
# Out:
# <Axes: >

# %%
np.array([1,2,3]) *np.random.randn(3)
# Out:
# array([0.37181707, 2.29256611, 2.28287659])

# %%
X.shape
# Out:
# (100, 100)
