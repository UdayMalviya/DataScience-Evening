# %%
import pandas as pd

# %%
df = pd.read_csv('../../Data/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# df
# train, val, test -> save
# train, val,  -> 80, 20

# %%
from sklearn.model_selection import train_test_split

# %%
len(df)*20 // 100
# Out:
# 56961

# %%
test  = df.sample(len(df)*30 // 100)

# %%
df.iloc[~test.index]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 8607     11612.0  1.031841 -0.480074  1.284097  0.551383 -1.234127 -0.180908
# 62384    50248.0  1.059700 -0.882254  0.748133 -1.173394 -1.491182 -0.899882
# 206174  136096.0  2.116907 -1.254577 -1.817242 -1.920991  1.291100  3.653453
# 142146   84590.0  1.227688 -0.538043  0.694117 -0.841786 -1.009983 -0.192264
# 251001  155163.0  2.119267 -0.776825 -1.541335 -0.791192 -0.280469 -0.195206
# ...          ...       ...       ...       ...       ...       ...       ...
# 13475    23855.0  1.330099  0.462710  0.033053  0.657645  0.221750 -0.442397
# 75246    55967.0  0.530870 -1.060385  1.788578 -1.732083 -1.376301  0.414278
# 146807   87898.0  2.062754 -0.016647 -1.116799  0.378874 -0.009935 -1.109608
# 207690  136795.0 -1.166132 -2.234434 -1.251235  1.711886  1.445764 -0.490628
# 153280   98420.0 -0.289570  1.977344  0.496922  4.500317  0.756145  0.758170
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 8607   -0.823551  0.095998  2.307650  ... -0.001148  0.236531  0.007198
# 62384  -0.538079 -0.053507  1.982126  ...  0.041283  0.092983 -0.105516
# 206174 -1.577821  0.970213 -0.082794  ... -0.036715 -0.235624  0.413303
# 142146 -0.781185  0.231505  2.117121  ... -0.029228  0.113835 -0.028820
# 251001 -0.891159 -0.040272  0.036473  ...  0.219406  0.635576  0.022896
# ...          ...       ...       ...  ...       ...       ...       ...
# 13475  -0.005498 -0.238154  1.337922  ... -0.500491 -1.175408  0.012672
# 75246  -1.128811  0.156930 -1.375147  ... -0.120356  0.379304  0.165412
# 146807  0.240072 -0.369940  0.436515  ... -0.286980 -0.667202  0.308113
# 207690  0.248125 -0.093335 -0.245484  ...  0.192819  1.349506  2.238323
# 153280  0.255853  0.462335 -0.804777  ... -0.333155 -0.729957  0.177268
#
#              V24       V25       V26       V27       V28  Amount  Class
# 8607    0.420524  0.016228  1.075350 -0.064337  0.018270   73.80      0
# 62384   0.442277  0.308444 -0.037582  0.022288  0.044004  111.89      0
# 206174  0.676576 -0.464603 -0.465983  0.029669 -0.043925   25.10      0
# 142146 -0.311916  0.413950 -0.628496  0.097796  0.024339    1.00      0
# 251001 -0.062231 -0.052535 -0.080399  0.021959 -0.004792   55.00      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 13475  -0.715229  0.338082  0.117144 -0.049068  0.014923    1.98      0
# 75246  -0.011888 -0.776591 -0.352115 -0.091144 -0.288934   11.00      0
# 146807 -0.089390 -0.255107  0.201970 -0.067010 -0.058863    7.23      0
# 207690  0.209642 -0.549070  0.802698  0.335087 -0.245712  140.00      0
# 153280  0.346177 -0.892770 -0.015066  0.311735  0.205629    8.45      0
#
# [85442 rows x 31 columns]

# %%
df =  df.drop(test.index)

# %%
len(df)/2
# Out:
# 142403.5

# %%
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 6            4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 9            9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# ...          ...       ...       ...       ...       ...       ...       ...
# 284799  172783.0 -1.775135 -0.004235  1.189786  0.331096  1.196063  5.519980
# 284800  172784.0  2.039560 -0.175233 -1.196825  0.234580 -0.008713 -0.726571
# 284803  172787.0 -0.732789 -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284805  172788.0 -0.240440  0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 1      -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 4       0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# 6      -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104
# 9       0.651583  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794
# ...          ...       ...       ...  ...       ...       ...       ...
# 284799 -1.518185  2.080825  1.159498  ...  0.103302  0.654850 -0.348929
# 284800  0.017050 -0.118228  0.435402  ... -0.268048 -0.717211  0.297930
# 284803  0.024330  0.294869  0.584800  ...  0.214205  0.924384  0.012463
# 284805 -0.686180  0.679145  0.392087  ...  0.265245  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# 6      -0.780055  0.750137 -0.257237  0.034507  0.005168    4.99      0
# 9      -0.385050 -0.069733  0.094199  0.246219  0.083076    3.68      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 284799  0.745323  0.704545 -0.127579  0.454379  0.130308   79.99      0
# 284800 -0.359769 -0.315610  0.201114 -0.080826 -0.075071    2.68      0
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00      0
#
# [199365 rows x 31 columns]

# %%
test.to_csv('../../Data/test_credit_card.csv', index=False, encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 199365 entries, 1 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    199365 non-null  float64
#  1   V1      199365 non-null  float64
#  2   V2      199365 non-null  float64
#  3   V3      199365 non-null  float64
#  4   V4      199365 non-null  float64
#  5   V5      199365 non-null  float64
#  6   V6      199365 non-null  float64
#  7   V7      199365 non-null  float64
#  8   V8      199365 non-null  float64
#  9   V9      199365 non-null  float64
#  10  V10     199365 non-null  float64
#  11  V11     199365 non-null  float64
#  12  V12     199365 non-null  float64
#  13  V13     199365 non-null  float64
#  14  V14     199365 non-null  float64
#  15  V15     199365 non-null  float64
#  16  V16     199365 non-null  float64
#  17  V17     199365 non-null  float64
#  18  V18     199365 non-null  float64
#  19  V19     199365 non-null  float64
#  20  V20     199365 non-null  float64
#  21  V21     199365 non-null  float64
#  22  V22     199365 non-null  float64
#  23  V23     199365 non-null  float64
#  24  V24     199365 non-null  float64
#  25  V25     199365 non-null  float64
#  26  V26     199365 non-null  float64
#  27  V27     199365 non-null  float64
#  28  V28     199365 non-null  float64
#  29  Amount  199365 non-null  float64
#  30  Class   199365 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 48.7 MB

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, y= 'Amount', x= df.index, hue='Class', alpha=0.3)
# Out:
# <Axes: xlabel='None', ylabel='Amount'>

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    199025
# 1       340
# Name: count, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *

# %%
pipe = Pipeline([
    ('scale', StandardScaler()),
    ('model', LogisticRegression(class_weight='balanced'))
])

# %%
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 6            4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 9            9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# ...          ...       ...       ...       ...       ...       ...       ...
# 284799  172783.0 -1.775135 -0.004235  1.189786  0.331096  1.196063  5.519980
# 284800  172784.0  2.039560 -0.175233 -1.196825  0.234580 -0.008713 -0.726571
# 284803  172787.0 -0.732789 -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284805  172788.0 -0.240440  0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 1      -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 4       0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# 6      -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104
# 9       0.651583  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794
# ...          ...       ...       ...  ...       ...       ...       ...
# 284799 -1.518185  2.080825  1.159498  ...  0.103302  0.654850 -0.348929
# 284800  0.017050 -0.118228  0.435402  ... -0.268048 -0.717211  0.297930
# 284803  0.024330  0.294869  0.584800  ...  0.214205  0.924384  0.012463
# 284805 -0.686180  0.679145  0.392087  ...  0.265245  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# 6      -0.780055  0.750137 -0.257237  0.034507  0.005168    4.99      0
# 9      -0.385050 -0.069733  0.094199  0.246219  0.083076    3.68      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 284799  0.745323  0.704545 -0.127579  0.454379  0.130308   79.99      0
# 284800 -0.359769 -0.315610  0.201114 -0.080826 -0.075071    2.68      0
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00      0
#
# [199365 rows x 31 columns]

# %%
X = df.drop()
y =

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='Class'), df['Class'], test_size=0.2, random_state=42, stratify=df['Class'])

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((159492, 30), (39873, 30), (159492,), (39873,))

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', LogisticRegression(class_weight='balanced'))])

# %%
y_pred = pipe.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
# Out:
# <Axes: >

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9764753091064129

# %%
recall_score(y_test, y_pred)
# Out:
# 0.9558823529411765

# %%
print(classification_report(y_test, y_pred
                     ))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     39805
#            1       0.07      0.96      0.12        68
#
#     accuracy                           0.98     39873
#    macro avg       0.53      0.97      0.55     39873
# weighted avg       1.00      0.98      0.99     39873

# %%
test = pd.read_csv('../../Data/test_credit_card.csv')

# %%
test_data = test.drop(columns='Class')

# %%
y_p = pipe.predict(test_data)

# %%
accuracy_score(test['Class'], y_p)
# Out:
# 0.9759837082465298

# %%
df.shape
# Out:
# (199365, 31)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
