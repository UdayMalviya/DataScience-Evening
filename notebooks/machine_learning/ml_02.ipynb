# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../Data/train.csv')

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# imputation 
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean', 'median', 'most_frequent', 'constant')

# %%
imputer
# Out:
# SimpleImputer()

# %%
# fit transform

# %%
imputer.fit(df[['Age']])
# Out:
# SimpleImputer()

# %%
imputer.transform(df[['Age']])
# Out:
# array([[22.        ],
#        [38.        ],
#        [26.        ],
#        [35.        ],
#        [35.        ],
#        [29.69911765],
#        [54.        ],
#        [ 2.        ],
#        [27.        ],
#        [14.        ],
#        [ 4.        ],
#        [58.        ],
#        [20.        ],
#        [39.        ],
#        [14.        ],
#        [55.        ],
#        [ 2.        ],
#        [29.69911765],
#        [31.        ],
#        [29.69911765],
#        [35.        ],
#        [34.        ],
#        [15.        ],
#        [28.        ],
#        [ 8.        ],
#        [38.        ],
#        [29.69911765],
#        [19.        ],
#        [29.69911765],
#        [29.69911765],
#        [40.        ],
#        [29.69911765],
#        [29.69911765],
#        [66.        ],
#        [28.        ],
#        [42.        ],
#        [29.69911765],
#        [21.        ],
#        [18.        ],
#        [14.        ],
#        [40.        ],
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 100, 791
sample_data = df.sample(100)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(sample_data.index)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
imputer = SimpleImputer(strategy='most_frequent', add_indicator=True)
imputer.fit_transform(df[['Cabin', 'Embarked']])
# Out:
# array([['C23 C25 C27', 'S', True, False],
#        ['C85', 'C', False, False],
#        ['C23 C25 C27', 'S', True, False],
#        ...,
#        ['C23 C25 C27', 'S', True, False],
#        ['C148', 'C', False, False],
#        ['C23 C25 C27', 'Q', True, False]], shape=(791, 4), dtype=object)

# %%
imputer.transform(df[['Cabin', 'Embarked']])
# Out:
# array([['C23 C25 C27', 'S', True, False],
#        ['C85', 'C', False, False],
#        ['C23 C25 C27', 'S', True, False],
#        ...,
#        ['C23 C25 C27', 'S', True, False],
#        ['C148', 'C', False, False],
#        ['C23 C25 C27', 'Q', True, False]], shape=(791, 4), dtype=object)

# %%
imputer.statistics_
# Out:
# array(['C23 C25 C27', 'S'], dtype=object)

# %%
imputer.get_feature_names_out()
# Out:
# array(['Cabin', 'Embarked', 'missingindicator_Cabin',
#        'missingindicator_Embarked'], dtype=object)

# %%
imputer.feature_names_in_
# Out:
# array(['Cabin', 'Embarked'], dtype=object)

# %%
z_score = |(x-mean) / std| > 3

# %%
arr = np.array([1,2,3,4,5,90])

# %%
np.abs((arr - np.mean(arr)) / len(arr))
# Out:
# array([ 2.75      ,  2.58333333,  2.41666667,  2.25      ,  2.08333333,
#        12.08333333])

# %%
x - median / mad

# %%
mad = np.abs(x - mean)/ n

# %%
np.abs((arr - np.mean(arr)) / len(arr))
# Out:
# array([-0.27272727,  0.64516129,  1.55172414,  2.44444444,  3.32      ,
#        89.71034483])

# %%
def mad(arr):
    mad = np.abs((arr - np.mean(arr)) / len(arr))
    return mad

# %%
mad(arr)
# Out:
# array([ 2.75      ,  2.58333333,  2.41666667,  2.25      ,  2.08333333,
#        12.08333333])

# %%
np.abs(arr - np.median(arr))/ mad(arr)
# Out:
# array([0.90909091, 0.58064516, 0.20689655, 0.22222222, 0.72      ,
#        7.15862069])

# %%
np.median(arr)
# Out:
# np.float64(3.5)

# %%
1 std above mean

# %%
m = 50000 
s = 10000
m + s
# Out:
# 60000

# %%
# 1 std 
# 2 std
# 3 extrme outler

# %%
# train test split 
# X_train, y_train, X_test, y_test 
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X.shape, y.shape
# Out:
# ((891, 11), (891,))

# %%
X_train, X_test, y_train, y_test =  train_test_split(X, y, train_size=0.8, random_state=42)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((712, 11), (712,), (179, 11), (179,))

# %%
imputer = SimpleImputer(strategy='median')

# %%
age = imputer.fit_transform(X_train[['Age']])

# %%
age
# Out:
# array([[45.5 ],
#        [23.  ],
#        [32.  ],
#        [26.  ],
#        [ 6.  ],
#        [24.  ],
#        [45.  ],
#        [29.  ],
#        [28.  ],
#        [28.  ],
#        [42.  ],
#        [36.  ],
#        [33.  ],
#        [17.  ],
#        [29.  ],
#        [50.  ],
#        [35.  ],
#        [38.  ],
#        [34.  ],
#        [17.  ],
#        [11.  ],
#        [61.  ],
#        [30.  ],
#        [ 7.  ],
#        [63.  ],
#        [20.  ],
#        [28.  ],
#        [29.  ],
#        [36.  ],
#        [28.  ],
#        [50.  ],
#        [27.  ],
#        [30.  ],
#        [33.  ],
#        [28.  ],
#        [28.  ],
#        [ 2.  ],
#        [25.  ],
#        [51.  ],
#        [25.  ],
#        [28.  ],
#        [28.  ],
#        [24.  ],
#        [18.  ],
#        [28.  ],
#        [25.  ],
#        [24.  ],
#        [22.  ],
#        [ 0.92],
#        [24.  ],
#        [26.  ],
#        [34.  ],
#        [21.  ],
#        [28.  ],
#        [28.  ],
# ...

# %%
X_train['Age'] = age

# %%
X_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 712 entries, 331 to 102
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Pclass       712 non-null    int64
#  2   Name         712 non-null    str
#  3   Sex          712 non-null    str
#  4   Age          712 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Ticket       712 non-null    str
#  8   Fare         712 non-null    float64
#  9   Cabin        159 non-null    str
#  10  Embarked     710 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 95.0 KB

# %%
X_test['Age'] = imputer.transform(X_test[['Age']])

# %%
X_test.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 179 entries, 709 to 10
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  179 non-null    int64
#  1   Pclass       179 non-null    int64
#  2   Name         179 non-null    str
#  3   Sex          179 non-null    str
#  4   Age          179 non-null    float64
#  5   SibSp        179 non-null    int64
#  6   Parch        179 non-null    int64
#  7   Ticket       179 non-null    str
#  8   Fare         179 non-null    float64
#  9   Cabin        45 non-null     str
#  10  Embarked     179 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 24.1 KB
