# %%
import pandas as pd 
import numpy as np
import sklearn as sk
import seaborn as sns

# %%
df = pd.read_csv("../../Data/CarPrice_Assignment.csv")

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    str
#  3   fueltype          205 non-null    str
#  4   aspiration        205 non-null    str
#  5   doornumber        205 non-null    str
#  6   carbody           205 non-null    str
#  7   drivewheel        205 non-null    str
#  8   enginelocation    205 non-null    str
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    str
#  15  cylindernumber    205 non-null    str
#  16  enginesize        205 non-null    int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    str
#  3   fueltype          205 non-null    str
#  4   aspiration        205 non-null    str
#  5   doornumber        205 non-null    str
#  6   carbody           205 non-null    str
#  7   drivewheel        205 non-null    str
#  8   enginelocation    205 non-null    str
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    str
#  15  cylindernumber    205 non-null    str
#  16  enginesize        205 non-null    int64
# ...

# %%
temp = {}
for i in df.columns:
    temp[i] = df[i].dtype

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
string = df.select_dtypes('string')

# %%
string.nunique()
# Out:
# CarName           147
# fueltype            2
# aspiration          2
# doornumber          2
# carbody             5
# drivewheel          3
# enginelocation      2
# enginetype          7
# cylindernumber      7
# fuelsystem          8
# dtype: int64

# %%
df['CarName'].value_counts()
# Out:
# CarName
# peugeot 504                 6
# toyota corona               6
# toyota corolla              6
# subaru dl                   4
# honda civic                 3
#                            ..
# volkswagen rabbit           1
# volkswagen rabbit custom    1
# volvo 245                   1
# volvo diesel                1
# volvo 246                   1
# Name: count, Length: 147, dtype: int64

# %%
string['CarName'].unique()
# Out:
# <ArrowStringArray>
# [      'alfa-romero giulia',      'alfa-romero stelvio',
#  'alfa-romero Quadrifoglio',              'audi 100 ls',
#                'audi 100ls',                 'audi fox',
#                 'audi 5000',                'audi 4000',
#       'audi 5000s (diesel)',                 'bmw 320i',
#  ...
#                 'vw rabbit',        'volkswagen rabbit',
#  'volkswagen rabbit custom',          'volvo 145e (sw)',
#               'volvo 144ea',              'volvo 244dl',
#                 'volvo 245',              'volvo 264gl',
#              'volvo diesel',                'volvo 246']
# Length: 147, dtype: str

# %%
# replace map
[1,2,3,4]{4: 7}

# %%
pd.Series([1,2,3,4]).replace({4:7})
# Out:
# 0    1
# 1    2
# 2    3
# 3    7
# dtype: int64

# %%
pd.Series([1,2,3,4]).map({4:7, 2: 4})
# Out:
# 0    NaN
# 1    4.0
# 2    NaN
# 3    7.0
# dtype: float64

# %%
class SimpleLinearReg:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self, x, y):
        _check_shape(x)
        self.m = np.sum((x - np.mean(x))*(y - np.mean(y))) / np.sum((x - np.mean(x))**2)
        self.b = np.mean(y) - m * np.mean(x)
        return m, b
    def predict(self, x):
        y = self.m* x + self.b
    def _check_shape(self, data):
        if data.ndim != 2:
            raise

# %%
obj = SimpleLinearReg()
obj.fit(np.array([1,1]), np.array([0]))
# Out:
# C:\Users\udaym\AppData\Local\Temp\ipykernel_11212\977876074.py:5: RuntimeWarning: invalid value encountered in scalar divide
#   m = np.sum((x - np.mean(x))*(y - np.mean(y))) / np.sum((x - np.mean(x))**2)
# (np.float64(nan), np.float64(nan))
