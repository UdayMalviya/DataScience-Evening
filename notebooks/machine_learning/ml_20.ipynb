# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../Data/PlayTennis.csv')

# %%
df
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 0      Sunny         Hot     High    Weak          No
# 1      Sunny         Hot     High  Strong          No
# 2   Overcast         Hot     High    Weak         Yes
# 3       Rain        Mild     High    Weak         Yes
# 4       Rain        Cool   Normal    Weak         Yes
# 5       Rain        Cool   Normal  Strong          No
# 6   Overcast        Cool   Normal  Strong         Yes
# 7      Sunny        Mild     High    Weak          No
# 8      Sunny        Cool   Normal    Weak         Yes
# 9       Rain        Mild   Normal    Weak         Yes
# 10     Sunny        Mild   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 12  Overcast         Hot   Normal    Weak         Yes
# 13      Rain        Mild     High  Strong          No

# %%
yes, no = df['Play Tennis'].value_counts()/len(df)

# %%
yes
# Out:
# 0.6428571428571429

# %%
no
# Out:
# 0.35714285714285715

# %%
entropy_tennis = -np.sum(
    (yes*(np.log2(yes)), no * (np.log2(no)))
)

# %%
entropy_tennis
# Out:
# np.float64(0.9402859586706311)

# %%
# Outlook -> sunny

# %%
df[df['Outlook']=='Sunny']
# Out:
#    Outlook Temperature Humidity    Wind Play Tennis
# 0    Sunny         Hot     High    Weak          No
# 1    Sunny         Hot     High  Strong          No
# 7    Sunny        Mild     High    Weak          No
# 8    Sunny        Cool   Normal    Weak         Yes
# 10   Sunny        Mild   Normal  Strong         Yes

# %%
sunny = (- (3/5) * np.log2(3/5) ) - ( (2/5) * (np.log2(2/5) ) )

# %%
df[df['Outlook']=='Rain']
# Out:
#    Outlook Temperature Humidity    Wind Play Tennis
# 3     Rain        Mild     High    Weak         Yes
# 4     Rain        Cool   Normal    Weak         Yes
# 5     Rain        Cool   Normal  Strong          No
# 9     Rain        Mild   Normal    Weak         Yes
# 13    Rain        Mild     High  Strong          No

# %%
rain = -np.sum(((3/5) * np.log2(3/5), (2/5) * (np.log2(2/5))))

# %%
rain, sunny, overcast
# Out:
# (np.float64(0.9709505944546686), np.float64(0.9709505944546686), 0)

# %%
df[df['Outlook']=='Overcast']
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 2   Overcast         Hot     High    Weak         Yes
# 6   Overcast        Cool   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 12  Overcast         Hot   Normal    Weak         Yes

# %%
4/4 * np.log2(1)
# Out:
# np.float64(0.0)

# %%
overcast = 0

# %%
weighted_entropy = 5/14 * sunny + 4/14 * overcast + 5/14 * rain

# %%
ig_outlook = entropy_tennis - weighted_entropy

# %%
outlook # IG
# Out:
# np.float64(0.24674981977443933)

# %%
# Temp

# %%
df[df['Temperature']=="Hot"]
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 0      Sunny         Hot     High    Weak          No
# 1      Sunny         Hot     High  Strong          No
# 2   Overcast         Hot     High    Weak         Yes
# 12  Overcast         Hot   Normal    Weak         Yes

# %%
hot = -np.sum((2/4 * np.log2(2/4), 2/4 * np.log2(2/4)))

# %%
hot
# Out:
# np.float64(1.0)

# %%
df[df['Temperature']=="Cool"]
# Out:
#     Outlook Temperature Humidity    Wind Play Tennis
# 4      Rain        Cool   Normal    Weak         Yes
# 5      Rain        Cool   Normal  Strong          No
# 6  Overcast        Cool   Normal  Strong         Yes
# 8     Sunny        Cool   Normal    Weak         Yes

# %%
cool = -np.sum((3/4 * np.log2(3/4), 1/4 * np.log2(1/4)))

# %%
cool
# Out:
# np.float64(0.8112781244591328)

# %%
df[df['Temperature']=='Mild']
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 3       Rain        Mild     High    Weak         Yes
# 7      Sunny        Mild     High    Weak          No
# 9       Rain        Mild   Normal    Weak         Yes
# 10     Sunny        Mild   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 13      Rain        Mild     High  Strong          No

# %%
mild = -np.sum((4/6 * np.log2(4/6), 2/6 * np.log2(2/6)))

# %%
mild
# Out:
# np.float64(0.9182958340544896)

# %%
temp_entropy = 4/14 * hot + 4/14 * cool + 6/14 * mild

# %%
temp_entropy
# Out:
# np.float64(0.9110633930116763)

# %%
ig_temp = entropy_tennis - temp_entropy

# %%
ig_temp
# Out:
# np.float64(0.02922256565895487)

# %%
ig_outlook, ig_temp
# Out:
# (np.float64(0.24674981977443933), np.float64(0.02922256565895487))
